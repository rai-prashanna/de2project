# %%
# Hello World - Get response from GitHub
# !curl https://api.github.com/zen
# Out:
# Responsive is better than fast.

# %%
# Get GitHub profile in JSON format
# !curl https://api.github.com/users/timbolo6
# Out:
# {
#   "login": "timbolo6",
#   "id": 42916893,
#   "node_id": "MDQ6VXNlcjQyOTE2ODkz",
#   "avatar_url": "https://avatars.githubusercontent.com/u/42916893?v=4",
#   "gravatar_id": "",
#   "url": "https://api.github.com/users/timbolo6",
#   "html_url": "https://github.com/timbolo6",
#   "followers_url": "https://api.github.com/users/timbolo6/followers",
#   "following_url": "https://api.github.com/users/timbolo6/following{/other_user}",
#   "gists_url": "https://api.github.com/users/timbolo6/gists{/gist_id}",
#   "starred_url": "https://api.github.com/users/timbolo6/starred{/owner}{/repo}",
#   "subscriptions_url": "https://api.github.com/users/timbolo6/subscriptions",
#   "organizations_url": "https://api.github.com/users/timbolo6/orgs",
#   "repos_url": "https://api.github.com/users/timbolo6/repos",
#   "events_url": "https://api.github.com/users/timbolo6/events{/privacy}",
#   "received_events_url": "https://api.github.com/users/timbolo6/received_events",
#   "type": "User",
# ...

# %%
# Get GitHub profile and the Http HEADER
# !curl -i https://api.github.com/users/timbolo6
# Out:
# HTTP/2 200
# server: GitHub.com
# date: Tue, 17 May 2022 11:17:28 GMT
# content-type: application/json; charset=utf-8
# cache-control: public, max-age=60, s-maxage=60
# vary: Accept, Accept-Encoding, Accept, X-Requested-With
# etag: W/"cc0f3790cb70ef331ac779552fd40f9bca07344b38d51beb75d9777ee45ca655"
# last-modified: Mon, 16 May 2022 10:07:46 GMT
# x-github-media-type: github.v3; format=json
# access-control-expose-headers: ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset
# access-control-allow-origin: *
# strict-transport-security: max-age=31536000; includeSubdomains; preload
# x-frame-options: deny
# x-content-type-options: nosniff
# x-xss-protection: 0
# referrer-policy: origin-when-cross-origin, strict-origin-when-cross-origin
# ...

# %%
# content-type: application/json; charset=utf-8
# X- are custom headers

## #####   Authentication #####
# Unauthenticated clients can make 60 request per hour
# x-ratelimit-limit: 60'
# x-ratelimit-remaining: 46'

# %% [markdown]
# ## Authentication

# %% [markdown]
# ### Using personal access token

# %%
#$ curl -i -u your_username:$token https://api.github.com/users/octocat
# !curl -i -u timbolo6:token https://api.github.com/users/timbolo6
# Out:
# HTTP/2 200
# server: GitHub.com
# date: Tue, 17 May 2022 11:34:27 GMT
# content-type: application/json; charset=utf-8
# content-length: 1316
# cache-control: private, max-age=60, s-maxage=60
# vary: Accept, Authorization, Cookie, X-GitHub-OTP
# etag: "4156e57105332df29e6441984a64cc05faaf15d002503a11221b532a28158e1a"
# last-modified: Mon, 16 May 2022 10:07:46 GMT
# x-oauth-scopes: admin:repo_hook, delete:packages, repo, write:packages
# x-accepted-oauth-scopes:
# github-authentication-token-expiration: 2022-06-10 18:04:35 UTC
# x-github-media-type: github.v3; format=json
# x-ratelimit-limit: 5000
# x-ratelimit-remaining: 4996
# x-ratelimit-reset: 1652790606
# x-ratelimit-used: 4
# x-ratelimit-resource: core
# ...

# %% [markdown]
# # Get Infos from Repositories

# %%
# !curl -i https://api.github.com/repos/twbs/bootstrap
# Out:
# HTTP/2 200
# server: GitHub.com
# date: Tue, 17 May 2022 11:35:12 GMT
# content-type: application/json; charset=utf-8
# cache-control: public, max-age=60, s-maxage=60
# vary: Accept, Accept-Encoding, Accept, X-Requested-With
# etag: W/"180b03898bf5f10ba390aebacf3c13c42bec2334acba38e154f54ff999937afd"
# last-modified: Tue, 17 May 2022 11:08:22 GMT
# x-github-media-type: github.v3; format=json
# access-control-expose-headers: ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset
# access-control-allow-origin: *
# strict-transport-security: max-age=31536000; includeSubdomains; preload
# x-frame-options: deny
# x-content-type-options: nosniff
# x-xss-protection: 0
# referrer-policy: origin-when-cross-origin, strict-origin-when-cross-origin
# ...

# %%
# !curl -i -u timbolo6:<token> https://api.github.com/users/timbolo6/repos
# Out:
# HTTP/2 200
# server: GitHub.com
# date: Tue, 17 May 2022 11:36:01 GMT
# content-type: application/json; charset=utf-8
# content-length: 45688
# cache-control: private, max-age=60, s-maxage=60
# vary: Accept, Authorization, Cookie, X-GitHub-OTP
# etag: "1743b9b90b7827db2d75942fffd69faa59629bd1ee7bdf442aa7c33345410ee7"
# x-oauth-scopes: admin:repo_hook, delete:packages, repo, write:packages
# x-accepted-oauth-scopes:
# github-authentication-token-expiration: 2022-06-10 18:04:35 UTC
# x-github-media-type: github.v3; format=json
# x-ratelimit-limit: 5000
# x-ratelimit-remaining: 4995
# x-ratelimit-reset: 1652790606
# x-ratelimit-used: 5
# x-ratelimit-resource: core
# access-control-expose-headers: ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset
# ...

# %%
# "language": "Jupyter Notebook",
